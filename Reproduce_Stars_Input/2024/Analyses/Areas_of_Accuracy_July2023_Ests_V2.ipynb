# %%
import pandas as pd
import warnings
from IPython.utils import io
import sys
import numpy as np
from functools import reduce

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

stars_dir = '~/GitHub/stars-data-builder/'
hos_dir = '~/Desktop/Rush/CMS_HospitalArchives/'

# %% [markdown]
# #
# ----
#
# # Find areas of accuracy
#
# The overall accuracy of estimates made in July 2023 was 71%. Perhaps, the accuracy was concentrated among particular hospitals.

# %%
def get_results(gen_info, stars_df_2024, exp_df):
    
    print('PPV = Positive Predictive Value = Precision')
    print('TPR = True Positive Rate\n')

    stars = [1,2,3,4,5]

    T_TP = 0
    T_TN = 0
    T_FP = 0
    T_FN = 0
    for star in stars:

        tdf = gen_info[gen_info['2023 overall star rating'] == str(star)]
        tdf = tdf[tdf['Retained 2022 Star'] == 1]
        
        hosps_2023 = tdf['PROVIDER_ID'].unique().tolist()

        TP = 0
        TN = 0
        FP = 0
        FN = 0
        for i, h_2023 in enumerate(hosps_2023):

            AP_df = stars_df_2024[stars_df_2024['PROVIDER_ID'] == h_2023]
            star_2024 = AP_df['star'].iloc[0]

            PP_df = exp_df[exp_df['PROVIDER_ID'] == h_2023]
            star_exp = PP_df['star'].iloc[0]

            if star_exp == star and star_2024 == star:
                TP += 1
            elif star_exp != star and star_2024 != star:
                TN += 1
            elif star_exp == star and star_2024 != star:
                FP += 1
            elif star_exp != star and star_2024 == star:
                FN += 1

        T_TP += TP
        T_TN += TN
        T_FP += FP
        T_FN += FN

        TPR = TP / (TP + FN) # aka Sensitivity
        FPR = FP / (FP + TN)
        TNR = TN / (TN + FP) # aka Specificity
        FNR = FN / (FN + TP)

        ACC = (TP + TN) / (TP + TN + FP + FN)
        PPV = TP / (TP + FP)
        NPV = TN / (TN + FN)

        F1 = 2 * (PPV * TPR) / (PPV + TPR)

        T = TP + TN + FP + FN
        print('For', T, 'hospitals that were', star, 'star in 2023:')
        print('    ' + f'{100*PPV:.2f}% PPV  ', TP+FP, 'hospitals were expected to stay a '+str(star)+'-star.', TP, 'actually did.')   
        print('    ' + f'{100*NPV:.2f}% NPV  ', TN+FN, 'hospitals were expected to change their rating.', TN, 'actually did.')   
        print('    ' + f'{100*TPR:.2f}% TPR  ', TP+FN, 'hospitals stayed a '+str(star)+'-star.', TP, 'of them were expected to.')
        print('    ' + f'{100*ACC:.2f}% Accuracy,  ', TP + TN, 'of', (TP + TN + FP + FN), 'hospitals kept or changed their star rating when expected to.')
    
        print('\n')


    TP = int(T_TP)
    TN = int(T_TN)
    FP = int(T_FP)
    FN = int(T_FN)

    TPR = TP / (TP + FN) # aka Sensitivity
    FPR = FP / (FP + TN)
    TNR = TN / (TN + FP) # aka Specificity
    FNR = FN / (FN + TP)

    ACC = (TP + TN) / (TP + TN + FP + FN)
    PPV = TP / (TP + FP)

    F1 = 2 * (PPV * TPR) / (PPV + TPR)

    print('FOR ALL', TP + TN + FP + FN, 'HOSPITALS IN 2023 THAT WERE ALSO IN 2024:')
    print('    ' + f'{100*PPV:.2f}% PPV,  ', TP+FP, 'hospitals were expected to keep their star rating.', TP, 'actually did.')   
    print('    ' + f'{100*NPV:.2f}% NPV,  ', TN+FN, 'hospitals were expected to change their rating.', TN, 'actually did.')   
    print('    ' + f'{100*TPR:.2f}% TPR,  ', TP+FN, 'hospitals kept their star rating.', TP, 'of them were expected to.')
    print('    ' + f'{100*ACC:.2f}% Accuracy,  ', TP + TN, 'of', (TP + TN + FP + FN), 'hospitals kept or changed their star rating when expected to.')
    return

# %% [markdown]
# #
# ------
# # Load and merge estimates of star ratings for 2024 with the actual outcomes

# %%
dates = ['July_2023', 'Oct_2023', 'Nov_2023', 'Jan_2024']

for lab in dates:
    print('------------------ ', lab, ' ------------------')
    
    groups = ['all']#, '3) # of groups=5', '2) # of groups=4', '1) # of groups=3']
    for group in groups:
        print('----------- ', group, ' -----------')
        
        stars_df_2024 = pd.read_csv(stars_dir + '2024/2024-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2024.csv')
        exp_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2024/SAS_output/CMS_Stars_2024_predictions_from_' + lab + '_data.csv')
        if group == 'all':
            pass
        else:
            stars_df_2024 = stars_df_2024[stars_df_2024['cnt_grp'] == group]
    
        ## Replace the imputed 666666 suffixes of VHA hospitals with their original 'F' suffix
        prvdrs1 = []
        for p in exp_df['PROVIDER_ID'].tolist():
            p = str(p)
            if '666666' in p:
                p = p[:-6] + 'F'
            while len(p) < 6:
                p = '0' + p
            prvdrs1.append(p)

        exp_df['PROVIDER_ID'] = prvdrs1

        print(stars_df_2024.shape)
        print(exp_df.shape)


        n_dir = stars_dir + 'CareCompare'
        ls = ['PROVIDER_ID', 'Hospital Name', 'State', '2023 overall star rating', '2022 overall star rating',
              'Hospital Type', 'Hospital Ownership', 'Emergency Services', 
              'month_year',
             ]

        tdf1 = pd.read_csv(n_dir + '/hospitals_01_2024/Hospital_General_Information.csv')
        tdf1['Facility ID'] = tdf1['Facility ID'].astype(str)

        tdf2 = pd.read_csv(n_dir + '/hospitals_04_2023/Hospital_General_Information.csv')
        tdf2['Facility ID'] = tdf2['Facility ID'].astype(str)

        cols1 = ['Facility ID', 'Facility Name', 'Hospital overall rating']
        cols2 = ['PROVIDER_ID', 'Hospital Name', '2022 overall star rating']
        cols3 = ['PROVIDER_ID', 'Hospital Name', '2023 overall star rating']

        for i, col in enumerate(cols1):
            if col in list(tdf1):
                tdf1.rename(columns={col: cols3[i]}, inplace=True)
            if col in list(tdf2):
                tdf2.rename(columns={col: cols2[i]}, inplace=True)


        tdf1 = tdf1.filter(items=ls, axis=1)
        tdf1['month_year'] = lab

        tdf2 = tdf2.filter(items=ls, axis=1)
        tdf2['month_year'] = lab


        print(list(tdf2))
        stars_2022 = tdf2['2022 overall star rating'].tolist()
        hosps_2022 = tdf2['PROVIDER_ID'].tolist()
        stars_2023 = tdf1['2023 overall star rating'].tolist()
        hosps_2023 = tdf1['PROVIDER_ID'].tolist()

        retained = []
        for i, hosp in enumerate(hosps_2023):
            star_2023 = stars_2023[i]

            if hosp in hosps_2022:
                ii = hosps_2022.index(hosp)
                star_2022 = stars_2022[ii]
                if star_2022 == star_2023:
                    retained.append(1)
                else:
                    retained.append(0)
            else:
                retained.append(0)

        tdf1['Retained 2022 Star'] = retained
        gen_info = tdf1.copy(deep=True)

        print('filtering out hospitals not included in 2024 stars estimates and outcomes:')
        
        gen_info = gen_info[gen_info['2023 overall star rating'].isin(['1','2','3','4','5'])]
        exp_df = exp_df[exp_df['star'].isin([1,2,3,4,5])]
        stars_df_2024 = stars_df_2024[stars_df_2024['star'].isin([1,2,3,4,5])] 
        
        hosps1 = stars_df_2024['PROVIDER_ID'].unique().tolist()
        hosps2 = gen_info['PROVIDER_ID'].unique().tolist()
        hosps3 = exp_df['PROVIDER_ID'].unique().tolist()
        
        
        hosps = list(set(hosps1) & set(hosps2) & set(hosps3))
        gen_info = gen_info[gen_info['PROVIDER_ID'].isin(hosps)]
        exp_df = exp_df[exp_df['PROVIDER_ID'].isin(hosps)]
        stars_df_2024 = stars_df_2024[stars_df_2024['PROVIDER_ID'].isin(hosps)] 
        
        print(gen_info.shape)

        get_results(gen_info, stars_df_2024, exp_df)
        print('\n\n')
# Out:
# ------------------  July_2023  ------------------
# -----------  all  -----------
# (4626, 27)
# (4677, 27)
# ['PROVIDER_ID', 'Hospital Name', 'State', '2022 overall star rating', 'Hospital Type', 'Hospital Ownership', 'Emergency Services', 'month_year']
# filtering out hospitals not included in 2024 stars estimates and outcomes:
# (2802, 9)
# PPV = Positive Predictive Value = Precision
# TPR = True Positive Rate
#
# For 110 hospitals that were 1 star in 2023:
#     83.91% PPV   87 hospitals were expected to stay a 1-star. 73 actually did.
#     82.61% NPV   23 hospitals were expected to change their rating. 19 actually did.
#     94.81% TPR   77 hospitals stayed a 1-star. 73 of them were expected to.
#     83.64% Accuracy,   92 of 110 hospitals kept or changed their star rating when expected to.
#
#
# For 295 hospitals that were 2 star in 2023:
#     67.89% PPV   190 hospitals were expected to stay a 2-star. 129 actually did.
#     75.24% NPV   105 hospitals were expected to change their rating. 79 actually did.
#     83.23% TPR   155 hospitals stayed a 2-star. 129 of them were expected to.
#     70.51% Accuracy,   208 of 295 hospitals kept or changed their star rating when expected to.
#
#
# For 332 hospitals that were 3 star in 2023:
#     63.51% PPV   211 hospitals were expected to stay a 3-star. 134 actually did.
#     68.60% NPV   121 hospitals were expected to change their rating. 83 actually did.
#     77.91% TPR   172 hospitals stayed a 3-star. 134 of them were expected to.
#     65.36% Accuracy,   217 of 332 hospitals kept or changed their star rating when expected to.
#
#
# For 325 hospitals that were 4 star in 2023:
#     71.94% PPV   196 hospitals were expected to stay a 4-star. 141 actually did.
#     70.54% NPV   129 hospitals were expected to change their rating. 91 actually did.
#     78.77% TPR   179 hospitals stayed a 4-star. 141 of them were expected to.
#     71.38% Accuracy,   232 of 325 hospitals kept or changed their star rating when expected to.
#
#
# For 217 hospitals that were 5 star in 2023:
#     90.27% PPV   113 hospitals were expected to stay a 5-star. 102 actually did.
#     64.42% NPV   104 hospitals were expected to change their rating. 67 actually did.
#     73.38% TPR   139 hospitals stayed a 5-star. 102 of them were expected to.
#     77.88% Accuracy,   169 of 217 hospitals kept or changed their star rating when expected to.
#
#
# FOR ALL 1279 HOSPITALS IN 2023 THAT WERE ALSO IN 2024:
#     72.65% PPV,   797 hospitals were expected to keep their star rating. 579 actually did.
#     64.42% NPV,   482 hospitals were expected to change their rating. 339 actually did.
#     80.19% TPR,   722 hospitals kept their star rating. 579 of them were expected to.
#     71.77% Accuracy,   918 of 1279 hospitals kept or changed their star rating when expected to.
#
#
#
# ------------------  Oct_2023  ------------------
# -----------  all  -----------
# (4626, 27)
# (4677, 27)
# ['PROVIDER_ID', 'Hospital Name', 'State', '2022 overall star rating', 'Hospital Type', 'Hospital Ownership', 'Emergency Services', 'month_year']
# filtering out hospitals not included in 2024 stars estimates and outcomes:
# (2802, 9)
# PPV = Positive Predictive Value = Precision
# TPR = True Positive Rate
#
# For 110 hospitals that were 1 star in 2023:
#     83.91% PPV   87 hospitals were expected to stay a 1-star. 73 actually did.
#     82.61% NPV   23 hospitals were expected to change their rating. 19 actually did.
#     94.81% TPR   77 hospitals stayed a 1-star. 73 of them were expected to.
#     83.64% Accuracy,   92 of 110 hospitals kept or changed their star rating when expected to.
#
#
# For 295 hospitals that were 2 star in 2023:
#     68.25% PPV   189 hospitals were expected to stay a 2-star. 129 actually did.
#     75.47% NPV   106 hospitals were expected to change their rating. 80 actually did.
#     83.23% TPR   155 hospitals stayed a 2-star. 129 of them were expected to.
#     70.85% Accuracy,   209 of 295 hospitals kept or changed their star rating when expected to.
#
#
# For 332 hospitals that were 3 star in 2023:
#     63.51% PPV   211 hospitals were expected to stay a 3-star. 134 actually did.
#     68.60% NPV   121 hospitals were expected to change their rating. 83 actually did.
#     77.91% TPR   172 hospitals stayed a 3-star. 134 of them were expected to.
#     65.36% Accuracy,   217 of 332 hospitals kept or changed their star rating when expected to.
#
#
# For 325 hospitals that were 4 star in 2023:
#     71.94% PPV   196 hospitals were expected to stay a 4-star. 141 actually did.
#     70.54% NPV   129 hospitals were expected to change their rating. 91 actually did.
#     78.77% TPR   179 hospitals stayed a 4-star. 141 of them were expected to.
#     71.38% Accuracy,   232 of 325 hospitals kept or changed their star rating when expected to.
#
#
# For 217 hospitals that were 5 star in 2023:
#     90.27% PPV   113 hospitals were expected to stay a 5-star. 102 actually did.
#     64.42% NPV   104 hospitals were expected to change their rating. 67 actually did.
#     73.38% TPR   139 hospitals stayed a 5-star. 102 of them were expected to.
#     77.88% Accuracy,   169 of 217 hospitals kept or changed their star rating when expected to.
#
#
# FOR ALL 1279 HOSPITALS IN 2023 THAT WERE ALSO IN 2024:
#     72.74% PPV,   796 hospitals were expected to keep their star rating. 579 actually did.
#     64.42% NPV,   483 hospitals were expected to change their rating. 340 actually did.
#     80.19% TPR,   722 hospitals kept their star rating. 579 of them were expected to.
#     71.85% Accuracy,   919 of 1279 hospitals kept or changed their star rating when expected to.
#
#
#
# ------------------  Nov_2023  ------------------
# -----------  all  -----------
# (4626, 27)
# (4673, 27)
# ['PROVIDER_ID', 'Hospital Name', 'State', '2022 overall star rating', 'Hospital Type', 'Hospital Ownership', 'Emergency Services', 'month_year']
# filtering out hospitals not included in 2024 stars estimates and outcomes:
# (2801, 9)
# PPV = Positive Predictive Value = Precision
# TPR = True Positive Rate
#
# For 110 hospitals that were 1 star in 2023:
#     83.53% PPV   85 hospitals were expected to stay a 1-star. 71 actually did.
#     76.00% NPV   25 hospitals were expected to change their rating. 19 actually did.
#     92.21% TPR   77 hospitals stayed a 1-star. 71 of them were expected to.
#     81.82% Accuracy,   90 of 110 hospitals kept or changed their star rating when expected to.
#
#
# For 296 hospitals that were 2 star in 2023:
#     72.47% PPV   178 hospitals were expected to stay a 2-star. 129 actually did.
#     77.97% NPV   118 hospitals were expected to change their rating. 92 actually did.
#     83.23% TPR   155 hospitals stayed a 2-star. 129 of them were expected to.
#     74.66% Accuracy,   221 of 296 hospitals kept or changed their star rating when expected to.
#
#
# For 332 hospitals that were 3 star in 2023:
#     68.50% PPV   200 hospitals were expected to stay a 3-star. 137 actually did.
#     73.48% NPV   132 hospitals were expected to change their rating. 97 actually did.
#     79.65% TPR   172 hospitals stayed a 3-star. 137 of them were expected to.
#     70.48% Accuracy,   234 of 332 hospitals kept or changed their star rating when expected to.
#
#
# For 325 hospitals that were 4 star in 2023:
#     79.77% PPV   173 hospitals were expected to stay a 4-star. 138 actually did.
#     73.03% NPV   152 hospitals were expected to change their rating. 111 actually did.
#     77.09% TPR   179 hospitals stayed a 4-star. 138 of them were expected to.
#     76.62% Accuracy,   249 of 325 hospitals kept or changed their star rating when expected to.
#
#
# For 216 hospitals that were 5 star in 2023:
#     92.24% PPV   116 hospitals were expected to stay a 5-star. 107 actually did.
#     69.00% NPV   100 hospitals were expected to change their rating. 69 actually did.
#     77.54% TPR   138 hospitals stayed a 5-star. 107 of them were expected to.
#     81.48% Accuracy,   176 of 216 hospitals kept or changed their star rating when expected to.
#
#
# FOR ALL 1279 HOSPITALS IN 2023 THAT WERE ALSO IN 2024:
#     77.39% PPV,   752 hospitals were expected to keep their star rating. 582 actually did.
#     69.00% NPV,   527 hospitals were expected to change their rating. 388 actually did.
#     80.72% TPR,   721 hospitals kept their star rating. 582 of them were expected to.
#     75.84% Accuracy,   970 of 1279 hospitals kept or changed their star rating when expected to.
#
#
#
# ------------------  Jan_2024  ------------------
# -----------  all  -----------
# (4626, 27)
# (4654, 27)
# ['PROVIDER_ID', 'Hospital Name', 'State', '2022 overall star rating', 'Hospital Type', 'Hospital Ownership', 'Emergency Services', 'month_year']
# filtering out hospitals not included in 2024 stars estimates and outcomes:
# (2806, 9)
# PPV = Positive Predictive Value = Precision
# TPR = True Positive Rate
#
# For 110 hospitals that were 1 star in 2023:
#     100.00% PPV   77 hospitals were expected to stay a 1-star. 77 actually did.
#     100.00% NPV   33 hospitals were expected to change their rating. 33 actually did.
#     100.00% TPR   77 hospitals stayed a 1-star. 77 of them were expected to.
#     100.00% Accuracy,   110 of 110 hospitals kept or changed their star rating when expected to.
#
#
# For 296 hospitals that were 2 star in 2023:
#     100.00% PPV   154 hospitals were expected to stay a 2-star. 154 actually did.
#     99.30% NPV   142 hospitals were expected to change their rating. 141 actually did.
#     99.35% TPR   155 hospitals stayed a 2-star. 154 of them were expected to.
#     99.66% Accuracy,   295 of 296 hospitals kept or changed their star rating when expected to.
#
#
# For 333 hospitals that were 3 star in 2023:
#     99.43% PPV   174 hospitals were expected to stay a 3-star. 173 actually did.
#     100.00% NPV   159 hospitals were expected to change their rating. 159 actually did.
#     100.00% TPR   173 hospitals stayed a 3-star. 173 of them were expected to.
#     99.70% Accuracy,   332 of 333 hospitals kept or changed their star rating when expected to.
#
#
# For 326 hospitals that were 4 star in 2023:
#     99.45% PPV   181 hospitals were expected to stay a 4-star. 180 actually did.
#     100.00% NPV   145 hospitals were expected to change their rating. 145 actually did.
#     100.00% TPR   180 hospitals stayed a 4-star. 180 of them were expected to.
#     99.69% Accuracy,   325 of 326 hospitals kept or changed their star rating when expected to.
#
#
# For 217 hospitals that were 5 star in 2023:
#     100.00% PPV   139 hospitals were expected to stay a 5-star. 139 actually did.
#     100.00% NPV   78 hospitals were expected to change their rating. 78 actually did.
#     100.00% TPR   139 hospitals stayed a 5-star. 139 of them were expected to.
#     100.00% Accuracy,   217 of 217 hospitals kept or changed their star rating when expected to.
#
#
# FOR ALL 1282 HOSPITALS IN 2023 THAT WERE ALSO IN 2024:
#     99.72% PPV,   725 hospitals were expected to keep their star rating. 723 actually did.
#     100.00% NPV,   557 hospitals were expected to change their rating. 556 actually did.
#     99.86% TPR,   724 hospitals kept their star rating. 723 of them were expected to.
#     99.77% Accuracy,   1279 of 1282 hospitals kept or changed their star rating when expected to.
