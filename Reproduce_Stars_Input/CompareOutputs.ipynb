# %%
import pandas as pd
import warnings
from IPython.utils import io
import sys
import numpy as np
from functools import reduce
#import xlsxwriter

from scipy.spatial import distance

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

stars_dir = '~/Desktop/Rush/CMS_Stars/'

# %% [markdown]
# # 2021

# %%
df_2021 = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2021/SAS_output/CMS_Stars_Apr_2021.csv')
prvdrs1 = df_2021['PROVIDER_ID'].unique()
print(df_2021.shape)

sas_2021 = pd.read_csv(stars_dir + '2021/2021-04 Stars Release/SAS_CSV_output/CMS_Stars_Apr_2021.csv')
prvdrs2 =sas_2021['PROVIDER_ID'].unique()
print(sas_2021.shape)

ls = np.setdiff1d(list(prvdrs1), list(prvdrs2))
print('hospitals in reproduced output, not in original output:', ls)

ls = np.setdiff1d(list(prvdrs2), list(prvdrs1))
print('hospitals in original output, not in reproduced output:', ls)

# There were two hospital in Stars data that were not in Hospitals Archive data
sas_2021 = sas_2021[sas_2021['PROVIDER_ID'].isin(df_2021['PROVIDER_ID'].unique())]

print('For 2021 Stars, there were 2 hospitals in the original output that were not in the reproduced output.')
print('\n')
print('Percent similarity scores:')
for c in list(df_2021):
    
    derived_x = df_2021[c].tolist()
    original_x = sas_2021[c].tolist()
    ids = df_2021['PROVIDER_ID'].tolist()
    tdf = pd.DataFrame(columns=['PROVIDER_ID', 'derived_x', 'original_x'])
    tdf['PROVIDER_ID'] = ids
    tdf['derived_x'] = derived_x
    tdf['original_x'] = original_x
    s1 = tdf.shape
    tdf.dropna(how='any', axis=0, inplace=True)
    s2 = tdf.shape
    
    derived_x = tdf['derived_x'].tolist()
    original_x = tdf['original_x'].tolist()
    
    try:
        d = 100 * (1 - distance.cosine(derived_x, original_x))
        print(c, ':', round(d, 4))
    except:
        pass
# Out:
# (4534, 27)
# (4536, 27)
# hospitals in reproduced output, not in original output: []
# hospitals in original output, not in reproduced output: [360367 451394]
# For 2021 Stars, there were 2 hospitals in the original output that were not in the reproduced output.
#
#
# Percent similarity scores:
# PROVIDER_ID : 100
# Std_Outcomes_Mortality_score : 100
# Std_Outcomes_Readmission_score : 99.9999
# Std_Outcomes_Safety_score : 100
# Std_PatientExp_score : 100
# Std_Process_score : 99.9978
# std_weight_PatientExperience : 100
# std_weight_Readmission : 100
# std_weight_Mortality : 100
# std_weight_safety : 100
# std_weight_Process : 100
# weight_PatientExperience : 100
# weight_Outcomes_Readmission : 99.9828
# weight_Outcomes_Mortality : 99.9995
# weight_Outcomes_Safety : 99.9994
# weight_Process : 100
# summary_score : 99.987
# Outcomes_Mortality_cnt : 100
# Outcomes_safety_cnt : 100
# Outcomes_Readmission_cnt : 99.9998
# Patient_Experience_cnt : 100
# Process_cnt : 99.9991
# ...

# %% [markdown]
# # 2022

# %%
df_2022 = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2022/SAS_output/CMS_Stars_Jul_2022.csv')
prvdrs1 = df_2022['PROVIDER_ID'].unique()
print(df_2022.shape)

sas_2022 = pd.read_csv(stars_dir + '2022/2022-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2022.csv')
prvdrs2 = sas_2022['PROVIDER_ID'].unique()
print(sas_2022.shape)

ls = np.setdiff1d(list(prvdrs1), list(prvdrs2))
print('hospitals in reproduced output, not in original output:', ls)

ls = np.setdiff1d(list(prvdrs2), list(prvdrs1))
print('hospitals in original output, not in reproduced output:', ls)

# There were two hospital in Stars data that were not in Hospitals Archive data
sas_2022 = sas_2022[sas_2022['PROVIDER_ID'].isin(df_2022['PROVIDER_ID'].unique())]

print('For 2022 Stars, there were 4 hospitals in the original output that were not in the reproduced output.')
print('\n')
print('Percent similarity scores:')

for c in list(df_2022):
    
    derived_x = df_2022[c].tolist()
    original_x = sas_2022[c].tolist()
    ids = df_2022['PROVIDER_ID'].tolist()
    tdf = pd.DataFrame(columns=['PROVIDER_ID', 'derived_x', 'original_x'])
    tdf['PROVIDER_ID'] = ids
    tdf['derived_x'] = derived_x
    tdf['original_x'] = original_x
    s1 = tdf.shape
    tdf.dropna(how='any', axis=0, inplace=True)
    s2 = tdf.shape
    
    derived_x = tdf['derived_x'].tolist()
    original_x = tdf['original_x'].tolist()
    
    try:
        d = 100.0 * (1 - distance.cosine(derived_x, original_x))
        print(c, ':', round(d,4))
    except:
        pass
# Out:
# (4485, 27)
# (4489, 27)
# hospitals in reproduced output, not in original output: []
# hospitals in original output, not in reproduced output: [191311 370214 670109 670265]
# For 2022 Stars, there were 4 hospitals in the original output that were not in the reproduced output.
#
#
# Percent similarity scores:
# PROVIDER_ID : 100.0
# Std_Outcomes_Mortality_score : 100.0
# Std_Outcomes_Readmission_score : 99.8401
# Std_Outcomes_Safety_score : 99.9822
# Std_PatientExp_score : 100.0
# Std_Process_score : 97.4518
# std_weight_PatientExperience : 100.0
# std_weight_Readmission : 100.0
# std_weight_Mortality : 100.0
# std_weight_safety : 100.0
# std_weight_Process : 100.0
# weight_PatientExperience : 99.9977
# weight_Outcomes_Readmission : 99.7018
# weight_Outcomes_Mortality : 99.9893
# weight_Outcomes_Safety : 99.9957
# weight_Process : 99.5403
# summary_score : 99.2244
# Outcomes_Mortality_cnt : 99.9406
# Outcomes_safety_cnt : 99.9701
# Outcomes_Readmission_cnt : 99.9405
# ...
