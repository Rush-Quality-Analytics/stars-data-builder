# %%
import pandas as pd
import warnings
from IPython.utils import io
import sys
import numpy as np
from functools import reduce
#import xlsxwriter

from scipy.spatial import distance

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

stars_dir = '~/GitHub/stars-data-builder/'

# %%
def get_results(sas_df, main_df, star_year):
    
    prvdrs1 = main_df['PROVIDER_ID'].unique()
    print('Shape of the reconstructed output file:', main_df.shape)

    prvdrs2 = sas_df['PROVIDER_ID'].unique()
    print('Shape of the original SAS output file:', sas_df.shape, '\n')

    ls = np.setdiff1d(list(prvdrs1), list(prvdrs2)).tolist()
    print(len(ls), "hospitals in the derived results file that aren't in the actual Stars results:", ls)

    ls = np.setdiff1d(list(prvdrs2), list(prvdrs1)).tolist()
    print(len(ls), "hospitals in the actual Stars results file that aren't in the derived file:", ls, '\n')

    tdf = sas_df[sas_df['star'].isin([1,2,3,4,5])]
    print('No. of actual star ratings:', tdf.shape[0], '\n')
    
    ls = list(set(prvdrs1) & set(prvdrs2))
    sas_df = sas_df[sas_df['PROVIDER_ID'].isin(ls)]
    sas_df.sort_values(by='PROVIDER_ID', ascending=False, inplace=True)
    main_df = main_df[main_df['PROVIDER_ID'].isin(ls)]
    main_df.sort_values(by='PROVIDER_ID', ascending=False, inplace=True)
    
    if sas_df['PROVIDER_ID'].tolist() == main_df['PROVIDER_ID'].tolist():
        print('After filtering, the ordered list of providers are the same')
    else:
        print('After filtering, the ordered list of providers are NOT the same')

    print('Results for', len(ls), 'common providers\n')
    
    print('Percent Perfect | Avg difference:')
    for c in list(main_df):
        if c == 'PROVIDER_ID' or c == 'star':
            continue
        
        derived_x = main_df[c].tolist()
        original_x = sas_df[c].tolist()
        ids = main_df['PROVIDER_ID'].tolist()
        tdf = pd.DataFrame(columns=['PROVIDER_ID', 'derived_x', 'original_x'])
        tdf['PROVIDER_ID'] = ids
        tdf['derived_x'] = derived_x
        tdf['original_x'] = original_x
        s1 = tdf.shape
        tdf.dropna(how='any', axis=0, inplace=True)
        s2 = tdf.shape

        derived_x = tdf['derived_x']#.tolist()
        original_x = tdf['original_x']#.tolist()

        try:
            d = np.abs(derived_x - original_x)
            d = d.tolist()
            d1 = 100 * d.count(0)/len(d)
            print(c, ':', round(d1, 4), '|', round(np.nanmean(d), 6))
        except:
            
            pass

    print('\n')
    pred_stars = main_df['star'].tolist()
    pred_prvdrs = main_df['PROVIDER_ID'].tolist()
    actual_stars = sas_df['star'].tolist()
    actual_prvdrs = sas_df['PROVIDER_ID'].tolist()

    #print(sorted(list(set(pred_stars))))
    #print(sorted(list(set(actual_stars))))
    #return
    stars = [1,2,3,4,5,'all']
    
    for star in stars:
        if star == 'all':
            print('For all 2024 hospitals with star ratings')
        else:
            print('For 2024 hospitals with', str(star) + '-star ratings')
            
        T_correct = 0
        T_incorrect = 0
        diffs = []
        for i, p in enumerate(pred_stars):
            a = actual_stars[i]
            if a != star and star != 'all':
                continue
            
            p1 = pred_prvdrs[i]
            p2 = actual_prvdrs[i]

            if p1 != p2:
                print(p1, 'is not', p2)
                return

            if np.isnan(a) and np.isnan(p):
                continue

            elif np.isnan(a):
                continue

            else:
                if p == a:
                    T_correct += 1
                elif p != a:
                    T_incorrect += 1
                    if p > 0:
                        diffs.append(p - a)

        print('Overall star ratings:')
        print('total correct:', T_correct)
        print('total incorrect:', T_incorrect)
        print('% correct:', np.round(100 * T_correct/(T_correct + T_incorrect), 3), '\n')

        print('Results for differences')
        for i in list(set(diffs)):
            if i < 0:
                print('Estimates were ', np.abs(i), 'stars less than the actual for', diffs.count(i), 'hospitals ')
            elif i > 0:
                print('Estimates were ', np.abs(i), 'stars greater than the actual for', diffs.count(i), 'hospitals ')

        #print(list(set(diffs)))
        #print(diffs.count(1), diffs.count(-1))
        #print(len(diffs))

        if len(diffs) > 0:
            perc = round(100*(diffs.count(1) + diffs.count(-1))/len(diffs), 2)
            perc = f'{perc:.2f}%'
            print(perc + ' of abs. differences were no greater than 1')
            print('\n')
    
    stars = [1,2,3,4,5]
    ct = 0
    for star in stars:
        tdf_main = main_df[main_df['star'] == star]
        tdf_sas = sas_df[sas_df['star'] == star]
        
        print(star, 'star hospitals:')
        print('No. predicted:', tdf_main.shape[0])
        ct += tdf_main.shape[0]
        print('No. actual:', tdf_sas.shape[0], '\n')
        
    print('No. of predicted stars:', ct)

# %% [markdown]
# # 2021

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2021/SAS_output/CMS_Stars_Apr_2021.csv')
sas_df = pd.read_csv(stars_dir + '2021/2021-04 Stars Release/SAS_CSV_output/CMS_Stars_Apr_2021.csv')
    
get_results(sas_df, main_df, '2021')
# Out:
# Shape of the reconstructed output file: (4536, 27)
# Shape of the original SAS output file: (4536, 27)
#
# 2 hospitals in the derived results file that aren't in the actual Stars results: [250152, 440133]
# 2 hospitals in the actual Stars results file that aren't in the derived file: [360367, 451394]
#
# No. of actual star ratings: 3355
#
# After filtering, the ordered list of providers are the same
# Results for 4534 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.000116
# Std_Outcomes_Readmission_score : 0.0 | 0.000158
# Std_Outcomes_Safety_score : 0.0 | 0.000159
# Std_PatientExp_score : 0.0 | 0.00013
# Std_Process_score : 0.0 | 0.000289
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 100.0 | 0.0
# weight_Outcomes_Readmission : 99.9544 | 9.2e-05
# weight_Outcomes_Mortality : 99.975 | 1.3e-05
# weight_Outcomes_Safety : 99.9722 | 1.4e-05
# weight_Process : 100.0 | 0.0
# summary_score : 0.0 | 0.000297
# Outcomes_Mortality_cnt : 100.0 | 0.0
# Outcomes_safety_cnt : 100.0 | 0.0
# Outcomes_Readmission_cnt : 99.9779 | 0.000221
# Patient_Experience_cnt : 100.0 | 0.0
# Process_cnt : 99.9338 | 0.000882
# Total_measure_group_cnt : 100.0 | 0.0
# MortSafe_Group_cnt : 100.0 | 0.0
# report_indicator : 100.0 | 0.0
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 204
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 690
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 1018
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 988
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 455
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 3355
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# 1 star hospitals:
# No. predicted: 204
# No. actual: 204
#
# 2 star hospitals:
# No. predicted: 690
# No. actual: 690
#
# 3 star hospitals:
# No. predicted: 1018
# No. actual: 1018
#
# 4 star hospitals:
# No. predicted: 988
# No. actual: 988
#
# 5 star hospitals:
# No. predicted: 455
# No. actual: 455
#
# No. of predicted stars: 3355

# %% [markdown]
# # 2022

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2022/SAS_output/CMS_Stars_Jul_2022.csv')
sas_df = pd.read_csv(stars_dir + '2022/2022-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2022.csv')

get_results(sas_df, main_df, '2022')
# Out:
# Shape of the reconstructed output file: (4491, 27)
# Shape of the original SAS output file: (4489, 27)
#
# 5 hospitals in the derived results file that aren't in the actual Stars results: [250152, 390197, 420057, 450780, 451381]
# 3 hospitals in the actual Stars results file that aren't in the derived file: [370214, 670109, 670265]
#
# No. of actual star ratings: 3121
#
# After filtering, the ordered list of providers are the same
# Results for 4486 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.000647
# Std_Outcomes_Readmission_score : 0.0 | 0.006948
# Std_Outcomes_Safety_score : 0.0 | 0.00285
# Std_PatientExp_score : 0.0 | 0.001309
# Std_Process_score : 0.0 | 0.002243
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 100.0 | 0.0
# weight_Outcomes_Readmission : 99.6446 | 0.001136
# weight_Outcomes_Mortality : 99.9216 | 4.9e-05
# weight_Outcomes_Safety : 99.9153 | 5.3e-05
# weight_Process : 99.5859 | 0.001267
# summary_score : 0.0 | 0.00385
# Outcomes_Mortality_cnt : 99.6656 | 0.008025
# Outcomes_safety_cnt : 99.7548 | 0.004458
# Outcomes_Readmission_cnt : 99.5542 | 0.015604
# Patient_Experience_cnt : 99.7325 | 0.0214
# Process_cnt : 99.5765 | 0.005573
# Total_measure_group_cnt : 99.5542 | 0.008694
# MortSafe_Group_cnt : 99.7994 | 0.002229
# report_indicator : 99.7994 | 0.002006
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 188
# total incorrect: 10
# % correct: 94.949
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 9 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 687
# total incorrect: 15
# % correct: 97.863
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 14 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 892
# total incorrect: 3
# % correct: 99.665
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 2 hospitals
# Estimates were  1.0 stars less than the actual for 1 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 891
# total incorrect: 4
# % correct: 99.553
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 1 hospitals
# Estimates were  1.0 stars less than the actual for 1 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 431
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 3089
# total incorrect: 32
# % correct: 98.975
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 26 hospitals
# Estimates were  1.0 stars less than the actual for 2 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# 1 star hospitals:
# No. predicted: 188
# No. actual: 198
#
# 2 star hospitals:
# No. predicted: 698
# No. actual: 702
#
# 3 star hospitals:
# No. predicted: 908
# No. actual: 895
#
# 4 star hospitals:
# No. predicted: 894
# No. actual: 895
#
# 5 star hospitals:
# No. predicted: 434
# No. actual: 431
#
# No. of predicted stars: 3122

# %% [markdown]
# # 2023

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2023/SAS_output/CMS_Stars_Jul_2023.csv')

## Replace the imputed 666666 suffixes of VHA hospitals with their original 'F' suffix
prvdrs1 = []
for p in main_df['PROVIDER_ID'].tolist():
    p = str(p)
    if '666666' in p:
        p = p[:-6] + 'F'
    while len(p) < 6:
        p = '0' + p
    prvdrs1.append(p)
    
main_df['PROVIDER_ID'] = prvdrs1

sas_df = pd.read_csv(stars_dir + '2023/2023-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2023.csv')

get_results(sas_df, main_df, '2023')
# Out:
# Shape of the reconstructed output file: (4684, 27)
# Shape of the original SAS output file: (4654, 27)
#
# 33 hospitals in the derived results file that aren't in the actual Stars results: ['02013F', '02014F', '05015F', '05020F', '05022F', '05039F', '05041F', '06003F', '10013F', '10021F', '11032F', '11033F', '11035F', '12001F', '17002F', '18003F', '19050F', '21007F', '25039F', '26002F', '29001F', '33025F', '34011F', '34014F', '36006F', '42009F', '45068F', '45069F', '45070F', '49001F', '49005F', '49008F', '50005F']
# 3 hospitals in the actual Stars results file that aren't in the derived file: ['251329', '640001', '670265']
#
# No. of actual star ratings: 3076
#
# After filtering, the ordered list of providers are the same
# Results for 4651 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.001637
# Std_Outcomes_Readmission_score : 0.0 | 0.002273
# Std_Outcomes_Safety_score : 0.0 | 0.01296
# Std_PatientExp_score : 0.0 | 0.009845
# Std_Process_score : 0.0 | 0.005764
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 99.8466 | 0.000228
# weight_Outcomes_Readmission : 99.796 | 0.000344
# weight_Outcomes_Mortality : 99.894 | 8.4e-05
# weight_Outcomes_Safety : 99.9431 | 6.4e-05
# weight_Process : 99.848 | 0.000303
# summary_score : 0.0 | 0.004368
# Outcomes_Mortality_cnt : 99.871 | 0.004085
# Outcomes_safety_cnt : 99.914 | 0.00129
# Outcomes_Readmission_cnt : 99.8065 | 0.005805
# Patient_Experience_cnt : 99.9785 | 0.00172
# Process_cnt : 99.5915 | 0.00645
# Total_measure_group_cnt : 99.785 | 0.003225
# MortSafe_Group_cnt : 99.914 | 0.00086
# report_indicator : 99.914 | 0.00086
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 236
# total incorrect: 14
# % correct: 94.4
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 14 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 655
# total incorrect: 13
# % correct: 98.054
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 8 hospitals
# Estimates were  1.0 stars less than the actual for 3 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 854
# total incorrect: 18
# % correct: 97.936
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 16 hospitals
# Estimates were  1.0 stars less than the actual for 1 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 791
# total incorrect: 12
# % correct: 98.506
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 8 hospitals
# Estimates were  1.0 stars less than the actual for 3 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 483
# total incorrect: 0
# % correct: 100.0
#
# Results for differences
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 3019
# total incorrect: 57
# % correct: 98.147
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 46 hospitals
# Estimates were  1.0 stars less than the actual for 7 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# 1 star hospitals:
# No. predicted: 239
# No. actual: 250
#
# 2 star hospitals:
# No. predicted: 670
# No. actual: 668
#
# 3 star hospitals:
# No. predicted: 865
# No. actual: 872
#
# 4 star hospitals:
# No. predicted: 807
# No. actual: 803
#
# 5 star hospitals:
# No. predicted: 491
# No. actual: 483
#
# No. of predicted stars: 3072

# %% [markdown]
# # 2024

# %% [markdown]
# ## Predictions made in July 2023

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2024/SAS_output/CMS_Stars_2024_predictions_from_July_2023_data.csv')

## Replace the imputed 666666 suffixes of VHA hospitals with their original 'F' suffix
prvdrs1 = []
for p in main_df['PROVIDER_ID'].tolist():
    p = str(p)
    if '666666' in p:
        p = p[:-6] + 'F'
    while len(p) < 6:
        p = '0' + p
    prvdrs1.append(p)
    
main_df['PROVIDER_ID'] = prvdrs1

sas_df = pd.read_csv(stars_dir + '2024/2024-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2024.csv')

get_results(sas_df, main_df, '2024')
# Out:
# Shape of the reconstructed output file: (4677, 27)
# Shape of the original SAS output file: (4626, 27)
#
# 72 hospitals in the derived results file that aren't in the actual Stars results: ['02013F', '02014F', '030077', '05015F', '05020F', '05022F', '05039F', '05041F', '050568', '050742', '06003F', '070039', '100070', '100081', '10013F', '10021F', '110130', '11032F', '11033F', '11035F', '12001F', '140040', '150004', '151335', '160008', '17002F', '18003F', '190146', '190307', '190314', '19050F', '21007F', '240063', '241300', '250152', '250163', '25039F', '26002F', '260064', '260209', '29001F', '290022', '330236', '33025F', '34011F', '34014F', '360037', '36006F', '370229', '390072', '420066', '420068', '42009F', '421303', '430013', '450078', '450099', '450348', '450586', '45068F', '450697', '45069F', '45070F', '450877', '451325', '451328', '49001F', '49005F', '49008F', '50005F', '501301', '670004']
# 21 hospitals in the actual Stars results file that aren't in the derived file: ['031320', '041332', '051309', '161315', '170208', '251329', '271333', '281330', '351305', '390338', '390339', '400127', '431340', '451301', '451307', '451397', '451398', '500052', '640001', '670265', '670319']
#
# No. of actual star ratings: 2847
#
# After filtering, the ordered list of providers are the same
# Results for 4605 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.06234
# Std_Outcomes_Readmission_score : 0.0 | 0.260902
# Std_Outcomes_Safety_score : 0.0 | 0.422714
# Std_PatientExp_score : 0.0 | 0.242208
# Std_Process_score : 0.0 | 0.339907
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 99.0858 | 0.000682
# weight_Outcomes_Readmission : 95.5388 | 0.00552
# weight_Outcomes_Mortality : 96.3387 | 0.003323
# weight_Outcomes_Safety : 97.7406 | 0.002028
# weight_Process : 95.3937 | 0.00628
# summary_score : 0.0 | 0.201724
# Outcomes_Mortality_cnt : 95.3963 | 0.047123
# Outcomes_safety_cnt : 86.9055 | 0.140065
# Outcomes_Readmission_cnt : 90.076 | 0.140282
# Patient_Experience_cnt : 97.6113 | 0.191097
# Process_cnt : 70.1194 | 0.359175
# Total_measure_group_cnt : 91.5092 | 0.087514
# MortSafe_Group_cnt : 98.3713 | 0.016287
# report_indicator : 99.1531 | 0.008469
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 205
# total incorrect: 72
# % correct: 74.007
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 66 hospitals
# Estimates were  2.0 stars greater than the actual for 4 hospitals
# Estimates were  3.0 stars greater than the actual for 1 hospitals
# 92.96% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 398
# total incorrect: 197
# % correct: 66.891
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 119 hospitals
# Estimates were  2.0 stars greater than the actual for 6 hospitals
# Estimates were  1.0 stars less than the actual for 66 hospitals
# 96.86% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 568
# total incorrect: 260
# % correct: 68.599
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 101 hospitals
# Estimates were  1.0 stars less than the actual for 153 hospitals
# Estimates were  2.0 stars less than the actual for 3 hospitals
# 98.83% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 494
# total incorrect: 272
# % correct: 64.491
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 37 hospitals
# Estimates were  3.0 stars less than the actual for 1 hospitals
# Estimates were  1.0 stars less than the actual for 218 hospitals
# Estimates were  2.0 stars less than the actual for 14 hospitals
# 94.44% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 220
# total incorrect: 161
# % correct: 57.743
#
# Results for differences
# Estimates were  3.0 stars less than the actual for 2 hospitals
# Estimates were  1.0 stars less than the actual for 154 hospitals
# Estimates were  2.0 stars less than the actual for 1 hospitals
# 98.09% of abs. differences were no greater than 1
#
#
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 1885
# total incorrect: 962
# % correct: 66.21
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 323 hospitals
# Estimates were  2.0 stars greater than the actual for 10 hospitals
# Estimates were  3.0 stars greater than the actual for 1 hospitals
# Estimates were  2.0 stars less than the actual for 18 hospitals
# Estimates were  3.0 stars less than the actual for 3 hospitals
# Estimates were  1.0 stars less than the actual for 591 hospitals
# 96.62% of abs. differences were no greater than 1
#
#
# 1 star hospitals:
# No. predicted: 277
# No. actual: 277
#
# 2 star hospitals:
# No. predicted: 638
# No. actual: 595
#
# 3 star hospitals:
# No. predicted: 917
# No. actual: 828
#
# 4 star hospitals:
# No. predicted: 765
# No. actual: 766
#
# 5 star hospitals:
# No. predicted: 257
# No. actual: 381
#
# No. of predicted stars: 2854

# %% [markdown]
# ## Predictions made in Oct 2023

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2024/SAS_output/CMS_Stars_2024_predictions_from_Oct_2023_data.csv')

## Replace the imputed 666666 suffixes of VHA hospitals with their original 'F' suffix
prvdrs1 = []
for p in main_df['PROVIDER_ID'].tolist():
    p = str(p)
    if '666666' in p:
        p = p[:-6] + 'F'
    while len(p) < 6:
        p = '0' + p
    prvdrs1.append(p)
    
main_df['PROVIDER_ID'] = prvdrs1

sas_df = pd.read_csv(stars_dir + '2024/2024-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2024.csv')

get_results(sas_df, main_df, '2024')
# Out:
# Shape of the reconstructed output file: (4677, 27)
# Shape of the original SAS output file: (4626, 27)
#
# 72 hospitals in the derived results file that aren't in the actual Stars results: ['02013F', '02014F', '030077', '05015F', '05020F', '05022F', '05039F', '05041F', '050568', '050742', '06003F', '070039', '100070', '100081', '10013F', '10021F', '110130', '11032F', '11033F', '11035F', '12001F', '140040', '150004', '151335', '160008', '17002F', '18003F', '190146', '190307', '190314', '19050F', '21007F', '240063', '241300', '250152', '250163', '25039F', '26002F', '260064', '260209', '29001F', '290022', '330236', '33025F', '34011F', '34014F', '360037', '36006F', '370229', '390072', '420066', '420068', '42009F', '421303', '430013', '450078', '450099', '450348', '450586', '45068F', '450697', '45069F', '45070F', '450877', '451325', '451328', '49001F', '49005F', '49008F', '50005F', '501301', '670004']
# 21 hospitals in the actual Stars results file that aren't in the derived file: ['031320', '041332', '051309', '161315', '170208', '251329', '271333', '281330', '351305', '390338', '390339', '400127', '431340', '451301', '451307', '451397', '451398', '500052', '640001', '670265', '670319']
#
# No. of actual star ratings: 2847
#
# After filtering, the ordered list of providers are the same
# Results for 4605 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.06234
# Std_Outcomes_Readmission_score : 0.0 | 0.260902
# Std_Outcomes_Safety_score : 0.0 | 0.422714
# Std_PatientExp_score : 0.0 | 0.242208
# Std_Process_score : 0.0 | 0.341353
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 99.0858 | 0.000682
# weight_Outcomes_Readmission : 95.5388 | 0.00552
# weight_Outcomes_Mortality : 96.3387 | 0.003323
# weight_Outcomes_Safety : 97.7406 | 0.002028
# weight_Process : 95.3937 | 0.00628
# summary_score : 0.0 | 0.202002
# Outcomes_Mortality_cnt : 95.3963 | 0.047123
# Outcomes_safety_cnt : 86.9055 | 0.140065
# Outcomes_Readmission_cnt : 90.076 | 0.140282
# Patient_Experience_cnt : 97.6113 | 0.191097
# Process_cnt : 70.0977 | 0.359175
# Total_measure_group_cnt : 91.5309 | 0.087296
# MortSafe_Group_cnt : 98.3713 | 0.016287
# report_indicator : 99.1531 | 0.008469
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 205
# total incorrect: 72
# % correct: 74.007
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 66 hospitals
# Estimates were  2.0 stars greater than the actual for 4 hospitals
# Estimates were  3.0 stars greater than the actual for 1 hospitals
# 92.96% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 398
# total incorrect: 197
# % correct: 66.891
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 119 hospitals
# Estimates were  2.0 stars greater than the actual for 6 hospitals
# Estimates were  1.0 stars less than the actual for 66 hospitals
# 96.86% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 569
# total incorrect: 259
# % correct: 68.72
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 99 hospitals
# Estimates were  1.0 stars less than the actual for 154 hospitals
# Estimates were  2.0 stars less than the actual for 3 hospitals
# 98.83% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 494
# total incorrect: 272
# % correct: 64.491
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 36 hospitals
# Estimates were  3.0 stars less than the actual for 1 hospitals
# Estimates were  1.0 stars less than the actual for 219 hospitals
# Estimates were  2.0 stars less than the actual for 14 hospitals
# 94.44% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 220
# total incorrect: 161
# % correct: 57.743
#
# Results for differences
# Estimates were  3.0 stars less than the actual for 2 hospitals
# Estimates were  1.0 stars less than the actual for 154 hospitals
# Estimates were  2.0 stars less than the actual for 1 hospitals
# 98.09% of abs. differences were no greater than 1
#
#
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 1886
# total incorrect: 961
# % correct: 66.245
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 320 hospitals
# Estimates were  2.0 stars greater than the actual for 10 hospitals
# Estimates were  3.0 stars greater than the actual for 1 hospitals
# Estimates were  2.0 stars less than the actual for 18 hospitals
# Estimates were  3.0 stars less than the actual for 3 hospitals
# Estimates were  1.0 stars less than the actual for 593 hospitals
# 96.61% of abs. differences were no greater than 1
#
#
# 1 star hospitals:
# No. predicted: 277
# No. actual: 277
#
# 2 star hospitals:
# No. predicted: 639
# No. actual: 595
#
# 3 star hospitals:
# No. predicted: 919
# No. actual: 828
#
# 4 star hospitals:
# No. predicted: 763
# No. actual: 766
#
# 5 star hospitals:
# No. predicted: 256
# No. actual: 381
#
# No. of predicted stars: 2854

# %% [markdown]
# ## Prediction made in Nov 2023

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2024/SAS_output/CMS_Stars_2024_predictions_from_Nov_2023_data.csv')

## Replace the imputed 666666 suffixes of VHA hospitals with their original 'F' suffix
prvdrs1 = []
for p in main_df['PROVIDER_ID'].tolist():
    p = str(p)
    if '666666' in p:
        p = p[:-6] + 'F'
    while len(p) < 6:
        p = '0' + p
    prvdrs1.append(p)
    
main_df['PROVIDER_ID'] = prvdrs1

sas_df = pd.read_csv(stars_dir + '2024/2024-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2024.csv')

get_results(sas_df, main_df, '2024')
# Out:
# Shape of the reconstructed output file: (4673, 27)
# Shape of the original SAS output file: (4626, 27)
#
# 60 hospitals in the derived results file that aren't in the actual Stars results: ['02013F', '02014F', '05015F', '05020F', '05022F', '05039F', '05041F', '050568', '050742', '06003F', '070039', '100070', '100081', '10013F', '10021F', '11032F', '11033F', '11035F', '12001F', '140040', '150004', '160008', '17002F', '18003F', '190146', '190307', '190314', '19050F', '21007F', '250152', '25039F', '26002F', '260064', '260209', '29001F', '290022', '330236', '33025F', '34011F', '34014F', '360037', '36006F', '370229', '420066', '420068', '42009F', '421303', '450078', '450099', '450586', '45068F', '45069F', '45070F', '450877', '451328', '49001F', '49005F', '49008F', '50005F', '670004']
# 13 hospitals in the actual Stars results file that aren't in the derived file: ['030074', '031320', '041332', '170208', '251329', '281316', '281330', '431340', '451397', '451398', '640001', '670265', '670319']
#
# No. of actual star ratings: 2847
#
# After filtering, the ordered list of providers are the same
# Results for 4613 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.06225
# Std_Outcomes_Readmission_score : 0.0 | 0.26054
# Std_Outcomes_Safety_score : 0.0 | 0.320045
# Std_PatientExp_score : 0.0 | 0.164557
# Std_Process_score : 0.0 | 0.22162
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 99.3425 | 0.000515
# weight_Outcomes_Readmission : 96.7299 | 0.003926
# weight_Outcomes_Mortality : 97.2618 | 0.002411
# weight_Outcomes_Safety : 98.3076 | 0.001444
# weight_Process : 96.477 | 0.00523
# summary_score : 0.0 | 0.151329
# Outcomes_Mortality_cnt : 95.426 | 0.046391
# Outcomes_safety_cnt : 91.5023 | 0.089313
# Outcomes_Readmission_cnt : 90.1366 | 0.138738
# Patient_Experience_cnt : 98.3091 | 0.13527
# Process_cnt : 77.9319 | 0.248645
# Total_measure_group_cnt : 94.1036 | 0.060048
# MortSafe_Group_cnt : 99.0679 | 0.009321
# report_indicator : 99.5448 | 0.004552
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 212
# total incorrect: 65
# % correct: 76.534
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 64 hospitals
# Estimates were  2.0 stars greater than the actual for 1 hospitals
# 98.46% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 428
# total incorrect: 167
# % correct: 71.933
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 100 hospitals
# Estimates were  2.0 stars greater than the actual for 2 hospitals
# Estimates were  1.0 stars less than the actual for 61 hospitals
# 98.77% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 608
# total incorrect: 220
# % correct: 73.43
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 67 hospitals
# Estimates were  1.0 stars less than the actual for 150 hospitals
# Estimates were  2.0 stars less than the actual for 1 hospitals
# 99.54% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 521
# total incorrect: 245
# % correct: 68.016
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 26 hospitals
# Estimates were  3.0 stars less than the actual for 1 hospitals
# Estimates were  1.0 stars less than the actual for 209 hospitals
# Estimates were  2.0 stars less than the actual for 8 hospitals
# 96.31% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 241
# total incorrect: 140
# % correct: 63.255
#
# Results for differences
# Estimates were  3.0 stars less than the actual for 1 hospitals
# Estimates were  1.0 stars less than the actual for 133 hospitals
# Estimates were  2.0 stars less than the actual for 2 hospitals
# 97.79% of abs. differences were no greater than 1
#
#
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 2010
# total incorrect: 837
# % correct: 70.601
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 257 hospitals
# Estimates were  2.0 stars greater than the actual for 3 hospitals
# Estimates were  2.0 stars less than the actual for 11 hospitals
# Estimates were  3.0 stars less than the actual for 2 hospitals
# Estimates were  1.0 stars less than the actual for 553 hospitals
# 98.06% of abs. differences were no greater than 1
#
#
# 1 star hospitals:
# No. predicted: 276
# No. actual: 277
#
# 2 star hospitals:
# No. predicted: 654
# No. actual: 595
#
# 3 star hospitals:
# No. predicted: 923
# No. actual: 828
#
# 4 star hospitals:
# No. predicted: 726
# No. actual: 766
#
# 5 star hospitals:
# No. predicted: 267
# No. actual: 381
#
# No. of predicted stars: 2846

# %% [markdown]
# ## Predictions made in January 2024

# %%
main_df = pd.read_csv(stars_dir + 'Reproduce_Stars_Input/2024/SAS_output/CMS_Stars_2024_predictions_from_Jan_2024_data.csv')

## Replace the imputed 666666 suffixes of VHA hospitals with their original 'F' suffix
prvdrs1 = []
for p in main_df['PROVIDER_ID'].tolist():
    p = str(p)
    if '666666' in p:
        p = p[:-6] + 'F'
    while len(p) < 6:
        p = '0' + p
    prvdrs1.append(p)
    
main_df['PROVIDER_ID'] = prvdrs1

sas_df = pd.read_csv(stars_dir + '2024/2024-07 Stars Release/SAS_CSV_output/CMS_Stars_Jul_2024.csv')

get_results(sas_df, main_df, '2024')
# Out:
# Shape of the reconstructed output file: (4654, 27)
# Shape of the original SAS output file: (4626, 27)
#
# 34 hospitals in the derived results file that aren't in the actual Stars results: ['02013F', '02014F', '05015F', '05020F', '05022F', '05039F', '05041F', '06003F', '10013F', '10021F', '11032F', '11033F', '11035F', '12001F', '17002F', '18003F', '19050F', '21007F', '250152', '25039F', '26002F', '29001F', '33025F', '34011F', '34014F', '36006F', '370229', '45068F', '45069F', '45070F', '49001F', '49005F', '49008F', '50005F']
# 6 hospitals in the actual Stars results file that aren't in the derived file: ['170208', '251329', '451397', '451398', '640001', '670265']
#
# No. of actual star ratings: 2847
#
# After filtering, the ordered list of providers are the same
# Results for 4620 common providers
#
# Percent Perfect | Avg difference:
# Std_Outcomes_Mortality_score : 0.0 | 0.000247
# Std_Outcomes_Readmission_score : 0.0 | 0.001185
# Std_Outcomes_Safety_score : 0.0 | 0.003465
# Std_PatientExp_score : 0.0 | 0.010095
# Std_Process_score : 0.0 | 0.004654
# std_weight_PatientExperience : 100.0 | 0.0
# std_weight_Readmission : 100.0 | 0.0
# std_weight_Mortality : 100.0 | 0.0
# std_weight_safety : 100.0 | 0.0
# std_weight_Process : 100.0 | 0.0
# weight_PatientExperience : 100.0 | 0.0
# weight_Outcomes_Readmission : 99.8403 | 0.00034
# weight_Outcomes_Mortality : 99.9162 | 7.4e-05
# weight_Outcomes_Safety : 99.9711 | 1.5e-05
# weight_Process : 99.8908 | 0.000387
# summary_score : 0.0 | 0.002982
# Outcomes_Mortality_cnt : 99.9567 | 0.000866
# Outcomes_safety_cnt : 99.9784 | 0.000216
# Outcomes_Readmission_cnt : 99.7835 | 0.003463
# Patient_Experience_cnt : 99.9784 | 0.001732
# Process_cnt : 99.7186 | 0.006277
# Total_measure_group_cnt : 99.8268 | 0.001948
# MortSafe_Group_cnt : 100.0 | 0.0
# report_indicator : 100.0 | 0.0
#
#
# For 2024 hospitals with 1-star ratings
# Overall star ratings:
# total correct: 276
# total incorrect: 1
# % correct: 99.639
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 1 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 2-star ratings
# Overall star ratings:
# total correct: 588
# total incorrect: 7
# % correct: 98.824
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 7 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 3-star ratings
# Overall star ratings:
# total correct: 827
# total incorrect: 1
# % correct: 99.879
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 1 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 4-star ratings
# Overall star ratings:
# total correct: 764
# total incorrect: 2
# % correct: 99.739
#
# Results for differences
# Estimates were  1.0 stars less than the actual for 2 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For 2024 hospitals with 5-star ratings
# Overall star ratings:
# total correct: 380
# total incorrect: 1
# % correct: 99.738
#
# Results for differences
# Estimates were  1.0 stars less than the actual for 1 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# For all 2024 hospitals with star ratings
# Overall star ratings:
# total correct: 2835
# total incorrect: 12
# % correct: 99.579
#
# Results for differences
# Estimates were  1.0 stars greater than the actual for 9 hospitals
# Estimates were  1.0 stars less than the actual for 3 hospitals
# 100.00% of abs. differences were no greater than 1
#
#
# 1 star hospitals:
# No. predicted: 276
# No. actual: 277
#
# 2 star hospitals:
# No. predicted: 589
# No. actual: 595
#
# 3 star hospitals:
# No. predicted: 836
# No. actual: 828
#
# 4 star hospitals:
# No. predicted: 766
# No. actual: 766
#
# 5 star hospitals:
# No. predicted: 380
# No. actual: 381
#
# No. of predicted stars: 2847
